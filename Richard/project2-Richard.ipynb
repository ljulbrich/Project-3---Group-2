# %%
import yfinance as yf

# %%
def get_stock_price(symbol):
    stock = yf.Ticker(symbol)
    stock_hist = stock.history(period='1d')
    return stock_hist['Close'][0]

symbol = input("Enter stock symbol (NKE): ").upper()
stock_price = get_stock_price(symbol)
print(f"The current price of {symbol} is {stock_price}")
# Out:
# The current price of MSFT is 428.739990234375

# %%
import requests
from bs4 import BeautifulSoup
def get_stock_price(symbol):
    stock = yf.Ticker(symbol)
    stock_hist = stock.history(period='1d')
    return stock_hist['Close'][0]

stocks=['CROX','DECK','ONON','WWW','DBI','WEYS','SHOO','SKX','BIRK','RCKY','VRA','NKE']

for symbol in stocks:
    try:
        stock_price = get_stock_price(symbol)
        print(f"The current price of {symbol} is {stock_price}")
    except Exception as e:
        print(f"couldn't find stock {symbol}: {e}")
# Out:
# The current price of CROX is 143.8000030517578
# The current price of DECK is 941.260009765625
# The current price of ONON is 35.380001068115234
# The current price of WWW is 11.210000038146973
# The current price of DBI is 10.930000305175781
# The current price of WEYS is 31.8799991607666
# The current price of SHOO is 42.279998779296875
# The current price of SKX is 61.2599983215332
# The current price of BIRK is 47.25
# The current price of RCKY is 27.1299991607666
# The current price of VRA is 6.800000190734863
# The current price of NKE is 93.9800033569336

# %%
import yfinance as yf
import csv

def get_stock_price(symbol):
    stock = yf.Ticker(symbol)
    stock_hist = stock.history(period='1d')
    return stock_hist['Close'][0]

stocks = ['CROX', 'DECK', 'ONON', 'WWW', 'DBI', 'WEYS', 'SHOO', 'SKX', 'BIRK', 'RCKY', 'VRA', 'NKE']

data = []

for symbol in stocks:
    try:
        stock_price = get_stock_price(symbol)
        # Round stock price to two decimal places
        stock_price = round(stock_price, 2)
        data.append([symbol, stock_price])
    except Exception as e:
        print(f"Couldn't find stock {symbol}: {e}")

# Exporting data to CSV file
csv_file = "stock_prices.csv"
with open(csv_file, 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Name", "Current Price"])  # Write header
    writer.writerows(data)

print(f"Data exported to {csv_file}")
# Out:
# Data exported to stock_prices.csv

# %%
import yfinance as yf
import csv

def get_52week_change(symbol):
    stock = yf.Ticker(symbol)
    info = stock.info
    return info.get('52WeekChange', 'N/A')

stocks = ['CROX', 'DECK', 'ONON', 'WWW', 'DBI', 'WEYS', 'SHOO', 'SKX', 'BIRK', 'RCKY', 'VRA', 'NKE']

data = []

for symbol in stocks:
    try:
        week_change = get_52week_change(symbol)
        week_change  = round(week_change , 2)
        data.append([symbol, week_change])
    except Exception as e:
        print(f"Couldn't find stock {symbol}: {e}")

# Exporting data to CSV file
csv_file = "52WeekChange_data_1.csv"
with open(csv_file, 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Name", "52WeekChange"])  # Write header
    writer.writerows(data)

print(f"Data exported to {csv_file}")
# Out:
# Data exported to 52WeekChange_data_1.csv

# %%
import requests
from bs4 import BeautifulSoup
def get_stock_info(symbol):
    stock=yf.Ticker(symbol)
    info=stock.info
    return info

stocks=['CROX','DECK','ONON','WWW','DBI','WEYS','SHOO','SKX','BIRK','RCKY','VRA','NKE']

for symbol in stocks:
    try:
        stock_info = get_stock_info(symbol)
        stock_price = stock_info.get('currentPrice', 'N/A')
        pe_ratio = stock_info.get('trailingPE', 'N/A')
        change_percent = stock_info.get('52WeekChange', 'N/A')

        print(f"Stock Symbol: {symbol}")
        print(f"Current Price: {stock_price}")
        print(f"PE Ratio: {pe_ratio}")
        print(f"Change Percent: {change_percent}") 
    except Exception as e:
        print(f"couldn't find stock {symbol}: {e}")
# Out:
# Stock Symbol: CROX
# Current Price: 145.75
# PE Ratio: 11.386719
# Change Percent: 0.13210523
# Stock Symbol: DECK
# Current Price: 930.5
# PE Ratio: 33.664978
# Change Percent: 1.0675218
# Stock Symbol: ONON
# Current Price: 35.22
# PE Ratio: 125.78572
# Change Percent: 0.08828056
# Stock Symbol: WWW
# Current Price: 10.79
# PE Ratio: N/A
# Change Percent: -0.33942252
# Stock Symbol: DBI
# Current Price: 10.83
# PE Ratio: 23.543478
# Change Percent: 0.27389276
# Stock Symbol: WEYS
# Current Price: 30.62
# PE Ratio: 9.659306
# Change Percent: 0.19333589
# Stock Symbol: SHOO
# Current Price: 42.42
# PE Ratio: 18.443478
# Change Percent: 0.17871034
# Stock Symbol: SKX
# Current Price: 61.32
# PE Ratio: 17.5702
# Change Percent: 0.309417
# Stock Symbol: BIRK
# Current Price: 46.59
# PE Ratio: 105.88637
# Change Percent: 0.17537308
# Stock Symbol: RCKY
# Current Price: 27.41
# PE Ratio: 19.439716
# Change Percent: 0.16039348
# Stock Symbol: VRA
# Current Price: 6.7
# PE Ratio: N/A
# Change Percent: 0.1394558
# Stock Symbol: NKE
# Current Price: 92.56
# PE Ratio: 27.223528
# Change Percent: -0.24019724

# %%
info = get_stock_info('CROX')
info
# Out:
# {'address1': 'Building 5',
#  'address2': '500 Eldorado Boulevard',
#  'city': 'Broomfield',
#  'state': 'CO',
#  'zip': '80021',
#  'country': 'United States',
#  'phone': '303 848 7000',
#  'website': 'https://www.crocs.com',
#  'industry': 'Footwear & Accessories',
#  'industryKey': 'footwear-accessories',
#  'industryDisp': 'Footwear & Accessories',
#  'sector': 'Consumer Cyclical',
#  'sectorKey': 'consumer-cyclical',
#  'sectorDisp': 'Consumer Cyclical',
#  'longBusinessSummary': 'Crocs, Inc., together with its subsidiaries, designs, develops, manufactures, markets, distributes, and sells casual lifestyle footwear and accessories for men, women, and children under Crocs and HEYDUDE Brand in the United States and internationally. The company offers various footwear products, including clogs, sandals, slides, flips, wedges, platforms, socks, boots, charms, flip flops, sneakers, and slippers. It sells its products through wholesalers, retail stores, e-commerce sites, third-party marketplaces, and kiosks/store-in-store locations. Crocs, Inc. was founded in 1999 and is headquartered in Broomfield, Colorado.',
#  'fullTimeEmployees': 7030,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Andrew  Rees',
#    'age': 56,
#    'title': 'CEO & Director',
#    'yearBorn': 1967,
#    'fiscalYear': 2022,
#    'totalPay': 2697650,
#    'exercisedValue': 0,
#    'unexercisedValue': 20290000},
#   {'maxAge': 1,
#    'name': 'Ms. Anne  Mehlman',
#    'age': 42,
#    'title': 'Executive VP & CFO',
#    'yearBorn': 1981,
#    'fiscalYear': 2022,
#    'totalPay': 1280973,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Michelle  Poole',
#    'age': 54,
#    'title': 'Executive VP & Brand President for Crocs',
#    'yearBorn': 1969,
#    'fiscalYear': 2022,
#    'totalPay': 1275222,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Adam  Michaels',
#    'age': 46,
#    'title': 'Executive VP & Chief Digital Officer',
#    'yearBorn': 1977,
#    'fiscalYear': 2022,
#    'totalPay': 1076672,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Richard J. Blackshaw',
#    'age': 59,
#    'title': 'Executive VP & Brand President for HEYDUDE',
#    'yearBorn': 1964,
#    'fiscalYear': 2022,
#    'totalPay': 1392616,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Thomas  Britt',
#    'title': 'Executive VP & Chief Information Officer',
#    'fiscalYear': 2022,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Marisa F. Jacobs',
#    'title': 'Global Head of Investor Relations',
#    'fiscalYear': 2022,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Daniel P. Hart',
#    'age': 64,
#    'title': 'Executive VP and Chief Legal & Risk Officer',
#    'yearBorn': 1959,
#    'fiscalYear': 2022,
#    'totalPay': 1242601,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Shannon  Sisler',
#    'age': 49,
#    'title': 'Executive VP & Chief People Officer',
#    'yearBorn': 1974,
#    'fiscalYear': 2022,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Erik  Olson',
#    'title': 'Senior Vice President of Global Sourcing & Product Execution',
#    'fiscalYear': 2022,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 1,
#  'boardRisk': 3,
#  'compensationRisk': 3,
#  'shareHolderRightsRisk': 7,
#  'overallRisk': 3,
#  'governanceEpochDate': 1711670400,
#  'compensationAsOfEpochDate': 1672444800,
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 143.8,
#  'open': 145.81,
#  'dayLow': 143.885,
#  'dayHigh': 146.79,
#  'regularMarketPreviousClose': 143.8,
#  'regularMarketOpen': 145.81,
#  'regularMarketDayLow': 143.885,
#  'regularMarketDayHigh': 146.79,
#  'beta': 1.999,
#  'trailingPE': 11.386719,
#  'forwardPE': 10.724797,
#  'volume': 1114281,
#  'regularMarketVolume': 1114281,
#  'averageVolume': 1519128,
#  'averageVolume10days': 1236150,
#  'averageDailyVolume10Day': 1236150,
#  'marketCap': 8817656832,
#  'fiftyTwoWeekLow': 74.0,
#  'fiftyTwoWeekHigh': 151.32,
#  'priceToSalesTrailing12Months': 2.225362,
#  'fiftyDayAverage': 117.48,
#  'twoHundredDayAverage': 103.31345,
#  'currency': 'USD',
#  'enterpriseValue': 10664732672,
#  'profitMargins': 0.20002002,
#  'floatShares': 58444000,
#  'sharesOutstanding': 60498500,
#  'sharesShort': 5504370,
#  'sharesShortPriorMonth': 4849453,
#  'sharesShortPreviousMonthDate': 1707955200,
#  'dateShortInterest': 1710460800,
#  'sharesPercentSharesOut': 0.091000006,
#  'heldPercentInsiders': 0.02902,
#  'heldPercentInstitutions': 0.95381,
#  'shortRatio': 4.08,
#  'shortPercentOfFloat': 0.1257,
#  'impliedSharesOutstanding': 60498500,
#  'bookValue': 24.034,
#  'priceToBook': 6.0643253,
#  'lastFiscalYearEnd': 1703980800,
#  'nextFiscalYearEnd': 1735603200,
#  'mostRecentQuarter': 1703980800,
#  'earningsQuarterlyGrowth': 0.841,
#  'netIncomeToCommon': 792566016,
#  'trailingEps': 12.8,
#  'forwardEps': 13.59,
#  'pegRatio': 1.8,
#  'lastSplitFactor': '2:1',
#  'lastSplitDate': 1181865600,
#  'enterpriseToRevenue': 2.692,
#  'enterpriseToEbitda': 9.695,
#  '52WeekChange': 0.13210523,
#  'SandP52WeekChange': 0.28136122,
#  'exchange': 'NMS',
#  'quoteType': 'EQUITY',
#  'symbol': 'CROX',
#  'underlyingSymbol': 'CROX',
#  'shortName': 'Crocs, Inc.',
#  'longName': 'Crocs, Inc.',
#  'firstTradeDateEpochUtc': 1139409000,
#  'timeZoneFullName': 'America/New_York',
#  'timeZoneShortName': 'EDT',
#  'uuid': '28166f72-2353-3b0b-bc03-31981380e626',
#  'messageBoardId': 'finmb_13639284',
#  'gmtOffSetMilliseconds': -14400000,
#  'currentPrice': 145.75,
#  'targetHighPrice': 164.0,
#  'targetLowPrice': 95.0,
#  'targetMeanPrice': 140.62,
#  'targetMedianPrice': 140.0,
#  'recommendationMean': 1.8,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 13,
#  'totalCash': 149288000,
#  'totalCashPerShare': 2.468,
#  'ebitda': 1099974016,
#  'totalDebt': 1996359936,
#  'quickRatio': 0.688,
#  'currentRatio': 1.304,
#  'totalRevenue': 3962347008,
#  'debtToEquity': 137.309,
#  'revenuePerShare': 64.548,
#  'returnOnAssets': 0.14292,
#  'returnOnEquity': 0.69773,
#  'freeCashflow': 646625344,
#  'operatingCashflow': 930444032,
#  'earningsGrowth': 0.891,
#  'revenueGrowth': 0.016,
#  'grossMargins': 0.55775,
#  'ebitdaMargins': 0.27761,
#  'operatingMargins': 0.22748,
#  'financialCurrency': 'USD',
#  'trailingPegRatio': None}

# %%
import yfinance as yf
import csv

def get_stock_info(symbol):
    stock = yf.Ticker(symbol)
    info = stock.info
    return info

stocks = ['CROX', 'DECK', 'ONON', 'WWW', 'DBI', 'WEYS', 'SHOO', 'SKX', 'BIRK', 'RCKY', 'VRA', 'NKE']

data = []

for symbol in stocks:
    try:
        stock_info = get_stock_info(symbol)
        name = stock_info.get('shortName', 'N/A')
        pe_ratio = stock_info.get('trailingPE', 'N/A')
        # Round PE ratio to two decimal places
        pe_ratio = round(pe_ratio, 2) if pe_ratio != 'N/A' else 'N/A'
        data.append([name, pe_ratio])
    except Exception as e:
        print(f"Couldn't find stock {symbol}: {e}")

# Exporting data to CSV file
csv_file = "stock_data_1.csv"
with open(csv_file, 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Name", "PE Ratio"])  # Write header
    writer.writerows(data)

print(f"Data exported to {csv_file}")
# Out:
# Data exported to stock_data_1.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read data from CSV file
df = pd.read_csv('stock_prices.csv')

# Create bar plot
plt.figure(figsize=(10, 6))
plt.bar(df['Name'], df['Current Price'], color='skyblue')
plt.xlabel('Stock Symbol')
plt.ylabel('Current Price')
plt.title('Current Prices of Stocks')
plt.xticks(rotation=45)
plt.tight_layout()

# Save plot to local computer
plt.savefig('stock_prices_bar_plot.png')

# Show plot (optional)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read data from CSV file
df = pd.read_csv('52WeekChange_data_1.csv')

# Create bar plot
plt.figure(figsize=(10, 6))
plt.bar(df['Name'], df['52WeekChange'], color='red')
plt.xlabel('Stock Symbol')
plt.ylabel('52WeekChange')
plt.title('52WeekChange of Stocks')
plt.xticks(rotation=45)
plt.tight_layout()

# Save plot to local computer
plt.savefig('52WeekChange_bar_plot.png')

# Show plot (optional)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read data from CSV file
df = pd.read_csv('stock_data_1.csv')

# Create bar plot
plt.figure(figsize=(10, 6))
plt.bar(df['Name'], df['PE Ratio'], color='green')
plt.xlabel('Stock Name')
plt.ylabel('PE Ratio')
plt.title('PE Ratio of Stocks')
plt.xticks(rotation=45)
plt.tight_layout()

# Save plot to local computer
plt.savefig('stock_data_1_bar_plot.png')

# Show plot (optional)
plt.show()
